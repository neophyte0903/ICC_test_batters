# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
batsman=pd.read_csv('dataset/ICC_test_bat.csv')

# %%
batsman
# Out:
#                     Player       Span  Mat  Inn  NO   Runs    HS    Avg 100  \
# 0     SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*  53.78  51
# 1         RT Ponting (AUS)  1995-2012  168  287  29  13378   257  51.85  41
# 2       JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224  55.37  45
# 3     R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270  52.31  36
# 4            AN Cook (ENG)  2006-2018  161  291  16  12472   294  45.35  33
# ...                    ...        ...  ...  ...  ..    ...   ...    ...  ..
# 2996       CA Snedden (NZ)  1947-1947    1    -   -      -     -      -   -
# 2997      VN Swamy (INDIA)  1955-1955    1    -   -      -     -      -   -
# 2998  Usman Shinwari (PAK)  2019-2019    1    -   -      -     -      -   -
# 2999    CM Willoughby (SA)  2003-2003    2    -   -      -     -      -   -
# 3000       JW Wilson (AUS)  1956-1956    1    -   -      -     -      -   -
#
# ...

# %%
batsman.shape
# Out:
# (3001, 12)

# %%
batsman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3001 entries, 0 to 3000
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          3001 non-null   object
#  1   Span            3001 non-null   object
#  2   Mat             3001 non-null   int64
#  3   Inn             3001 non-null   object
#  4   NO              3001 non-null   object
#  5   Runs            3001 non-null   object
#  6   HS              3001 non-null   object
#  7   Avg             3001 non-null   object
#  8   100             3001 non-null   object
#  9   50              3001 non-null   object
#  10  0               3001 non-null   object
#  11  Player Profile  3001 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 281.5+ KB

# %%
batsman.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inn', 'NO', 'Runs', 'HS', 'Avg', '100', '50',
#        '0', 'Player Profile'],
#       dtype='object')

# %%
batsman.drop('Player Profile',axis=1,inplace=True)

# %%
batsman.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inn', 'NO', 'Runs', 'HS', 'Avg', '100', '50',
#        '0'],
#       dtype='object')

# %%
batsman.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inn       0
# NO        0
# Runs      0
# HS        0
# Avg       0
# 100       0
# 50        0
# 0         0
# dtype: int64

# %%
batsman[batsman['100'].isnull()]
# Out:
#                        Player       Span  Mat  Inn   NO Runs   HS  Avg  100  \
# 2981  Ali Hussain Rizvi (PAK)  1997-1997    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2982           PJ Allan (AUS)  1965-1965    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2983            JC Clay (ENG)  1935-1935    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2984          DJ Cullen (AUS)  2006-2006    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2985          HT Dani (INDIA)  1952-1952    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2986      Farrukh Zaman (PAK)  1976-1976    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2987           AB Howard (WI)  1972-1972    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2988             A Khan (ENG)  2009-2009    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2989       JCW MacBryan (ENG)  1924-1924    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2990           LR Pierre (WI)  1948-1948    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2991   V Rajindernath (INDIA)  1952-1952    1  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
batsman.replace('-',np.nan,inplace=True)

# %%
batsman.isnull().sum()
# Out:
# Player     0
# Span       0
# Mat        0
# Inn       20
# NO        20
# Runs      20
# HS        20
# Avg       88
# 100       20
# 50        20
# 0         20
# dtype: int64

# %%
batsman['Runs']=batsman['Runs'].fillna(0)
batsman['HS']=batsman['HS'].fillna(0)
batsman['100']=batsman['100'].fillna(0)
batsman['50']=batsman['50'].fillna(0)
batsman['0']=batsman['0'].fillna(0)

# %%
batsman[batsman['Inn'].isnull()]
# Out:
#                        Player       Span  Mat  Inn   NO Runs HS  Avg 100 50  0
# 2981  Ali Hussain Rizvi (PAK)  1997-1997    1  NaN  NaN    0  0  NaN   0  0  0
# 2982           PJ Allan (AUS)  1965-1965    1  NaN  NaN    0  0  NaN   0  0  0
# 2983            JC Clay (ENG)  1935-1935    1  NaN  NaN    0  0  NaN   0  0  0
# 2984          DJ Cullen (AUS)  2006-2006    1  NaN  NaN    0  0  NaN   0  0  0
# 2985          HT Dani (INDIA)  1952-1952    1  NaN  NaN    0  0  NaN   0  0  0
# 2986      Farrukh Zaman (PAK)  1976-1976    1  NaN  NaN    0  0  NaN   0  0  0
# 2987           AB Howard (WI)  1972-1972    1  NaN  NaN    0  0  NaN   0  0  0
# 2988             A Khan (ENG)  2009-2009    1  NaN  NaN    0  0  NaN   0  0  0
# 2989       JCW MacBryan (ENG)  1924-1924    1  NaN  NaN    0  0  NaN   0  0  0
# 2990           LR Pierre (WI)  1948-1948    1  NaN  NaN    0  0  NaN   0  0  0
# 2991   V Rajindernath (INDIA)  1952-1952    1  NaN  NaN    0  0  NaN   0  0  0
# ...

# %%
batsman['Inn']=batsman['Inn'].fillna('DNB')

# %%
batsman.tail(20)
# Out:
#                        Player       Span  Mat  Inn   NO Runs HS  Avg 100 50  0
# 2981  Ali Hussain Rizvi (PAK)  1997-1997    1  DNB  NaN    0  0  NaN   0  0  0
# 2982           PJ Allan (AUS)  1965-1965    1  DNB  NaN    0  0  NaN   0  0  0
# 2983            JC Clay (ENG)  1935-1935    1  DNB  NaN    0  0  NaN   0  0  0
# 2984          DJ Cullen (AUS)  2006-2006    1  DNB  NaN    0  0  NaN   0  0  0
# 2985          HT Dani (INDIA)  1952-1952    1  DNB  NaN    0  0  NaN   0  0  0
# 2986      Farrukh Zaman (PAK)  1976-1976    1  DNB  NaN    0  0  NaN   0  0  0
# 2987           AB Howard (WI)  1972-1972    1  DNB  NaN    0  0  NaN   0  0  0
# 2988             A Khan (ENG)  2009-2009    1  DNB  NaN    0  0  NaN   0  0  0
# 2989       JCW MacBryan (ENG)  1924-1924    1  DNB  NaN    0  0  NaN   0  0  0
# 2990           LR Pierre (WI)  1948-1948    1  DNB  NaN    0  0  NaN   0  0  0
# 2991   V Rajindernath (INDIA)  1952-1952    1  DNB  NaN    0  0  NaN   0  0  0
# ...

# %%
Play50= batsman=batsman[batsman['Mat']>100]
Play50
# Out:
#                       Player       Span  Mat  Inn  NO   Runs    HS    Avg 100  \
# 0       SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*  53.78  51
# 1           RT Ponting (AUS)  1995-2012  168  287  29  13378   257  51.85  41
# 2         JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224  55.37  45
# 3       R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270  52.31  36
# 4              AN Cook (ENG)  2006-2018  161  291  16  12472   294  45.35  33
# ..                       ...        ...  ...  ...  ..    ...   ...    ...  ..
# 461  M Muralitharan (ICC/SL)  1992-2010  133  164  56   1261    67  11.67   0
# 487        JM Anderson (ENG)  2003-2019  150  211  89   1181    81   9.68   0
# 580            CA Walsh (WI)  1984-2001  132  185  61    936   30*   7.54   0
# 730             M Ntini (SA)  1998-2009  101  116  45    699   32*   9.84   0
# 766         GD McGrath (AUS)  1993-2007  124  138  51    641    61   7.36   0
#
#      50   0
# 0    68  14
# ...

# %%
Play50.tail(40)
# Out:
#                       Player       Span  Mat  Inn  NO  Runs    HS    Avg 100  \
# 24          AJ Stewart (ENG)  1990-2003  133  235  21  8463   190  39.54  15
# 25            DI Gower (ENG)  1978-1992  117  204  18  8231   215  44.25  18
# 26        KP Pietersen (ENG)  2005-2014  104  181   8  8181   227  47.28  23
# 27           G Boycott (ENG)  1964-1982  108  193  23  8114  246*  47.72  22
# 29            ME Waugh (AUS)  1991-2002  128  209  17  8029  153*  41.81  20
# 30         MA Atherton (ENG)  1989-2001  115  212   7  7728  185*  37.69  16
# 31             IR Bell (ENG)  2004-2015  118  205  24  7727   235  42.69  22
# 32           JL Langer (AUS)  1993-2007  105  182  12  7696   250  45.27  23
# 33          MC Cowdrey (ENG)  1954-1975  114  188  15  7624   182  44.06  22
# 34         CG Greenidge (WI)  1974-1991  108  185  16  7558   226  44.72  19
# 36           MA Taylor (AUS)  1989-1999  104  186  13  7525  334*  43.49  19
# ...
